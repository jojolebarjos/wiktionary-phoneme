# %% [markdown]
# # Explore French headers

# %%
# Register tools
import os
import sys

sys.path.append(os.path.abspath("../"))

# %%
from collections import Counter

import regex as re

from tqdm import tqdm

from extract import iterate_dump

# %%
# Look at French corpus
path = "../frwiktionary-latest-pages-articles.xml.bz2"

# %%
# Process the whole dump
with open("header.txt", "w", encoding="utf-8", newline="\n") as file:
    for title, text in tqdm(iterate_dump(path)):

        # Add header to easily go back to source page
        file.write(f"\n>>> {title} <<<\n")
        for line in text.split("\n"):

            # Check for markdown header
            if line[:2] == "==":
                file.write(line)
                file.write("\n")
# Out:
# 3820284it [10:20, 6161.59it/s]

# %%
# Load lines
with open("header.txt", "r", encoding="utf-8", newline="\n") as file:
    lines = [line.rstrip("\n") for line in file]

# %%
# Show extract
for line in lines[:50]:
    print(line)
# Out:
# >>> accueil <<<
# == {{langue|fr}} ==
# === {{S|étymologie}} ===
# === {{S|nom|fr}} ===
# ==== {{S|dérivés}} ====
# ==== {{S|apparentés}} ====
# ==== {{S|synonymes}} ====
# ==== {{S|traductions}} ====
# ===== {{S|traductions à trier}} =====
# === {{S|prononciation}} ===
# === {{S|anagrammes}} ===
# === {{S|voir aussi}} ===
# === {{S|références}} ===
#
# >>> lire <<<
# == {{langue|fr}} ==
# === {{S|étymologie}} ===
# === {{S|verbe|fr}} ===
# ==== {{S|dérivés}} ====
# ==== {{S|traductions}} ====
# ===== {{S|traductions à trier}} =====
# === {{S|nom|fr}} ===
# ==== {{S|méronymes}} ====
# ==== {{S|synonymes}} ====
# ==== {{S|traductions}} ====
# === {{S|prononciation}} ===
# ==== {{S|homophones|fr}} ====
# === {{S|anagrammes}} ===
# === {{S|voir aussi}} ===
# == {{langue|fro}} ==
# === {{S|étymologie}} ===
# === {{S|nom|fro}} ===
# == {{langue|af}} ==
# === {{S|étymologie}} ===
# === {{S|nom|af}} ===
#
# >>> encyclopédie <<<
# == {{langue|fr}} ==
# === {{S|étymologie}} ===
# === {{S|nom|fr}} ===
# ==== {{S|variantes orthographiques}} ====
# ==== {{S|dérivés}} ====
# ==== {{S|traductions}} ====
# === {{S|verbe|fr|flexion}} ===
# === {{S|prononciation}} ===
# === {{S|voir aussi}} ===
# === {{S|références}} ===
#
# >>> manga <<<

# %%
# Count most common templates
template_r = re.compile(r"\{\{[^\|\{\}]+[\|\}]")
counter = Counter()
for line in tqdm(lines):
    counter.update(template_r.findall(line))
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 19434218/19434218 [01:40<00:00, 194118.71it/s]

# %%
# Show most common ones
counter.most_common()
# Out:
# [('{{S|', 7753999),
#  ('{{langue|', 4008622),
#  ('{{caractère}', 30564),
#  ('{{ar-racine/page|', 21),
#  ('{{lien|', 10),
#  ('{{eo-azotit}', 6),
#  ('{{note}', 5),
#  ('{{ S|', 5),
#  ('{{pron|', 5),
#  ('{{usage}', 4),
#  ('{{S |', 3),
#  ('{{zh|', 2),
#  ('{{note|', 2),
#  ('{{S[références}', 1),
#  ('{{lang|', 1),
#  ('{{hyponymes|', 1),
#  ('{{antonymes}', 1),
#  ('{{vocabulaire}', 1),
#  ('{{fr-rég|', 1)]

# %%
# Collect "syn" templates
template_r = re.compile(r"\{\{S\|.+\}\}")
counter = Counter()
for line in tqdm(lines):
    counter.update(template_r.findall(line))
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 19434218/19434218 [01:31<00:00, 211599.52it/s]

# %%
# Show most common ones
counter.most_common(50)
# Out:
# [('{{S|étymologie}}', 1269079),
#  ('{{S|verbe|fr|flexion}}', 1125197),
#  ('{{S|références}}', 514795),
#  ('{{S|traductions}}', 340365),
#  ('{{S|prononciation}}', 295239),
#  ('{{S|voir aussi}}', 255278),
#  ('{{S|nom|se|flexion}}', 233047),
#  ('{{S|nom|fr}}', 213113),
#  ('{{S|synonymes}}', 167776),
#  ('{{S|nom|fr|flexion}}', 158659),
#  ('{{S|notes}}', 132790),
#  ('{{S|verbe|se|flexion}}', 127123),
#  ('{{S|nom de famille|ru|flexion}}', 120473),
#  ('{{S|dérivés}}', 111402),
#  ('{{S|adjectif|fr|flexion}}', 108884),
#  ('{{S|verbe|bg|flexion}}', 107467),
#  ('{{S|nom propre|fr}}', 101015),
#  ('{{S|verbe|es|flexion}}', 85503),
#  ('{{S|anagrammes}}', 64886),
#  ('{{S|adjectif|fr}}', 63444),
#  ('{{S|apparentés}}', 58185),
#  ('{{S|vocabulaire}}', 50492),
#  ('{{S|nom|en|flexion}}', 50308),
#  ('{{S|verbe|eo|flexion}}', 43542),
#  ('{{S|variantes orthographiques}}', 43436),
#  ('{{S|verbe|fr}}', 43150),
#  ('{{S|nom|en}}', 41622),
#  ('{{S|variantes}}', 40349),
#  ('{{S|verbe|en|flexion}}', 39593),
#  ('{{S|écriture}}', 39265),
#  ('{{S|variante typographique|eo}}', 39215),
#  ('{{S|verbe|it|flexion}}', 37054),
#  ('{{S|nom|eo|flexion}}', 32761),
#  ('{{S|antonymes}}', 32281),
#  ('{{S|nom|it}}', 31679),
#  ('{{S|gentilés}}', 31445),
#  ('{{S|nom|bg|flexion}}', 29383),
#  ('{{S|nom|sl|flexion}}', 24100),
#  ('{{S|verbe|hsb|flexion}}', 23730),
#  ('{{S|nom|la|flexion}}', 22048),
#  ('{{S|verbe|la|flexion}}', 21811),
#  ('{{S|dico sinogrammes}}', 21252),
#  ('{{S|hyperonymes}}', 20855),
#  ('{{S|sinogramme|zh}}', 19298),
#  ('{{S|nom|mg|flexion}}', 18723),
#  ('{{S|homophones|fr}}', 18260),
#  ('{{S|adjectif|la|flexion}}', 18174),
#  ('{{S|adjectif|se|flexion}}', 17816),
#  ('{{S|verbe|pt|flexion}}', 17733),
#  ('{{S|nom|nl}}', 17730)]

# %%
# Count tags
template_r = re.compile(r"\{\{S\|([^\|]*).*\}\}")
tag_counter = Counter()
for key, count in counter.items():
    tag = template_r.match(key).group(1)
    tag_counter[tag] += count

# %%
# Show all
tag_counter.most_common()
# Out:
# [('verbe', 1838191),
#  ('nom', 1359901),
#  ('étymologie', 1269081),
#  ('références', 514795),
#  ('adjectif', 375419),
#  ('traductions', 340365),
#  ('prononciation', 295239),
#  ('voir aussi', 255278),
#  ('nom propre', 195128),
#  ('nom de famille', 167874),
#  ('synonymes', 167776),
#  ('notes', 132790),
#  ('dérivés', 111402),
#  ('anagrammes', 64886),
#  ('apparentés', 58185),
#  ('vocabulaire', 50492),
#  ('variantes orthographiques', 43436),
#  ('sinogramme', 41639),
#  ('variante typographique', 40762),
#  ('variantes', 40349),
#  ('écriture', 39265),
#  ('prénom', 36620),
#  ('antonymes', 32281),
#  ('gentilés', 31445),
#  ('adverbe', 28023),
#  ('dico sinogrammes', 21252),
#  ('hyperonymes', 20855),
#  ('homophones', 20235),
#  ('taux de reconnaissance', 16835),
#  ('dérivés autres langues', 16140),
#  ('Références', 12836),
#  ('paronymes', 12611),
#  ('hyponymes', 9205),
#  ('variantes dialectales', 7577),
#  ('quasi-synonymes', 7272),
#  ('symbole', 6525),
#  ('composés', 6064),
#  ('adjectif numéral', 5961),
#  ('interjection', 4029),
#  ('suffixe', 3824),
#  ('lettre', 3756),
#  ('préposition', 3310),
#  ('abréviations', 3059),
#  ('déclinaison', 2999),
#  ('holonymes', 2966),
#  ('préfixe', 2712),
#  ('pronom personnel', 2462),
#  ('traductions à trier', 2410),
#  ('locution-phrase', 2334),
#  ('phrases', 2272),
#  ('numéral', 2008),
#  ('méronymes', 1982),
#  ('conjonction', 1663),
#  ('adj', 1655),
#  ('pronom', 1184),
#  ('voir', 1114),
#  ('nom scientifique', 1002),
#  ('pronom indéfini', 745),
#  ('adjectif possessif', 693),
#  ('nom commun', 663),
#  ('conjugaison', 563),
#  ('modification phonétique', 520),
#  ('pronom démonstratif', 508),
#  ('pronom interrogatif', 490),
#  ('particule', 480),
#  ('transcriptions', 418),
#  ('variante par contrainte typographique', 397),
#  ('locution phrase', 396),
#  ('diminutifs', 382),
#  ('onomatopée', 381),
#  ('adverbe interrogatif', 354),
#  ('particule numérale', 350),
#  ('noms vernaculaires', 350),
#  ('radical', 346),
#  ('adjectif indéfini', 345),
#  ('expressions', 337),
#  ('erreur', 290),
#  ('pronom possessif', 285),
#  ('pronom relatif', 277),
#  ('adjectif démonstratif', 265),
#  ('article défini', 257),
#  ('faux-amis', 241),
#  ('classificateur', 210),
#  ('anciennes orthographes', 187),
#  ('conjonction de coordination', 153),
#  ('Voir aussi', 142),
#  ('postposition', 140),
#  ('bibliographie', 123),
#  ('article indéfini', 112),
#  ('Synonymes', 108),
#  ('verb', 108),
#  ('attestations', 98),
#  ('sources', 96),
#  ('adv', 94),
#  ('citations', 77),
#  ('Prononciation', 71),
#  ('adjectif interrogatif', 70),
#  ('phrase', 65),
#  ('infixe', 60),
#  ('Étymologie', 58),
#  ('Dérivés', 55),
#  ('proverbe', 50),
#  ('nom-pr', 42),
#  ('Anagrammes', 40),
#  ('locution', 38),
#  ('adverbe relatif', 34),
#  ('Apparentés', 26),
#  ('Variantes orthographiques', 26),
#  ('quantificateur', 25),
#  ('Vocabulaire', 24),
#  ('nom propre ', 24),
#  ('article', 23),
#  ('troponymes', 22),
#  ('Variantes', 22),
#  ('Notes', 22),
#  ('Antonymes', 20),
#  ('Hyperonymes', 19),
#  ('déterminant', 18),
#  ('adjectif ', 18),
#  ('article partitif', 17),
#  ('interfixe', 14),
#  ('trad-trier', 12),
#  ('adjectif exclamatif', 11),
#  ('adj-num', 11),
#  ('Holonymes', 10),
#  ('gismu', 10),
#  ('pronom-indéf', 10),
#  ('interj', 9),
#  ('nom ', 9),
#  ('substantif', 9),
#  ('variantes ', 9),
#  ('Méronymes', 9),
#  ('Variante par contrainte typographique', 9),
#  ('Abréviations', 9),
#  ('onom', 9),
#  ('préposition ', 7),
#  ('Hyponymes', 7),
#  ('affixe', 7),
#  ('faute d’orthographe', 7),
#  ('conj', 6),
#  ('pronom personnel ', 5),
#  ('augmentatifs', 5),
#  ('augm', 5),
#  ('vidéos', 5),
#  ('Expressions', 5),
#  ('circonfixe', 5),
#  ('adverbe pronominal', 4),
#  ('Traductions', 4),
#  ('Quasi-synonymes', 4),
#  ('Composés', 4),
#  ('Prénom', 4),
#  ('verbe ', 4),
#  ('encl', 4),
#  ('nom-fam', 4),
#  ('Infixe', 4),
#  ('patronyme', 4),
#  ('Nom commun', 4),
#  ('Nom', 4),
#  ('prép', 4),
#  ('pré-verbe', 4),
#  ('translittérations', 3),
#  ('Sources', 3),
#  ('Bibliographie', 3),
#  ('conjonction ', 3),
#  ('Phrases', 3),
#  ('Nom propre', 3),
#  ('adjectif relatif', 3),
#  ('préf', 3),
#  ('faute', 3),
#  ('Variantes dialectales', 3),
#  (' dérivés', 3),
#  ('Adverbe', 3),
#  ('Pronom démonstratif', 3),
#  ('adverbe indéfini', 2),
#  ('dérivés ', 2),
#  ('copule', 2),
#  ('note', 2),
#  (' synonymes', 2),
#  ('Adjectif', 2),
#  (' variantes orthographiques', 2),
#  ('class', 2),
#  (' références', 2),
#  ('Gentilés', 2),
#  ('Homophones', 2),
#  ('prov', 2),
#  ('interjection ', 2),
#  ('dérivés autres langues ', 2),
#  ('variantes dialectales ', 1),
#  ('Préposition', 1),
#  ('Pronom', 1),
#  ('var-ortho', 1),
#  ('adj-excl', 1),
#  ('adjectif numéral ', 1),
#  ('synonymes}} / {{S', 1),
#  ('pronom ', 1),
#  ('variantes orthographiques ', 1),
#  ('adv-pron', 1),
#  ('src', 1),
#  ('article indéfini ', 1),
#  (' quasi-synonymes', 1),
#  ('var', 1),
#  ('dérivés}} de [[modèle:ar-lbn', 1),
#  ('dérivés}} de [[modèle:ar-qSd', 1),
#  ('', 1),
#  ('Conjugaison', 1),
#  ('enclitique', 1),
#  (' voir aussi', 1),
#  ('pré-nom', 1),
#  ('gent', 1),
#  ('suff', 1),
#  ('Pronom personnel', 1),
#  ('Dérivés autres langues', 1),
#  (' adjectif ', 1),
#  (' variantes', 1),
#  (' apparentés', 1),
#  ('vocabulaire}', 1),
#  ('adverbe interrogatif ', 1),
#  ('Adverbe interrogatif', 1),
#  ('déclinaison ', 1),
#  ('dérivés}} de [[modèle:ar-ktb', 1),
#  ('dérivés}} de [[modèle:ar-f3l', 1),
#  ('dérivés}} de [[modèle:ar-slm', 1),
#  ('prénom ', 1),
#  ('pronom indéfini ', 1),
#  ('dérivés}} de [[modèle:ar-Hdd', 1),
#  ('dérivés}} de [[modèle:ar-SRr', 1),
#  ('prononciation ', 1),
#  ('adverbe ', 1),
#  ('dérivés}} de [[modèle:ar-kwn', 1),
#  ('Suffixe', 1),
#  ('dérivés}} de [[modèle:ar-bd3', 1),
#  ('dérivés}} de [[modèle:ar-Xlq', 1),
#  ("dérivés}} de [[modèle:ar-'lh", 1),
#  ('dérivés}} de [[modèle:ar-smw', 1),
#  ("dérivés}} de la forme  [[modèle:ar-'sm", 1),
#  ("dérivés}} de [[modèle:ar-'sm", 1),
#  ("dérivés}} de [[modèle:ar-'rD", 1),
#  ('dérivés}} de [[modèle:ar-tXm', 1),
#  ('dérivés}} de [[modèle:ar-wXm', 1),
#  ('suffixe ', 1),
#  ('dérivés}} de [[modèle:ar-by3', 1),
#  ('dérivés}} de [[modèle:ar-jls', 1),
#  ('dérivés}} de [[modèle:ar-dbr', 1),
#  ("dérivés}} de [[modèle:ar-'wn", 1),
#  ('synonymes ', 1),
#  ('Locution-phrase', 1),
#  ('tran', 1)]

# %%
# Only consider level 3 "syn" tags
template_r = re.compile(r"^=== \{\{S\|([^\|]*).*\}\}")
counter = Counter()
for line in tqdm(lines):
    match = template_r.match(line)
    if match is not None:
        counter[match.group(1)] += 1
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 19434218/19434218 [00:51<00:00, 378261.30it/s]

# %%
# Show all
counter.most_common()
# Out:
# [('verbe', 1838145),
#  ('nom', 1359844),
#  ('étymologie', 1269023),
#  ('références', 513225),
#  ('adjectif', 375399),
#  ('prononciation', 295048),
#  ('voir aussi', 254711),
#  ('nom propre', 195115),
#  ('nom de famille', 167874),
#  ('anagrammes', 64658),
#  ('sinogramme', 41633),
#  ('variante typographique', 40761),
#  ('prénom', 36620),
#  ('adverbe', 28008),
#  ('dico sinogrammes', 21252),
#  ('taux de reconnaissance', 16835),
#  ('Références', 12829),
#  ('symbole', 6525),
#  ('adjectif numéral', 5961),
#  ('interjection', 4026),
#  ('suffixe', 3822),
#  ('lettre', 3756),
#  ('préposition', 3308),
#  ('préfixe', 2712),
#  ('pronom personnel', 2461),
#  ('locution-phrase', 2332),
#  ('numéral', 2008),
#  ('conjonction', 1663),
#  ('adj', 1652),
#  ('pronom', 1183),
#  ('voir', 1057),
#  ('nom scientifique', 1002),
#  ('pronom indéfini', 742),
#  ('adjectif possessif', 693),
#  ('nom commun', 662),
#  ('modification phonétique', 518),
#  ('pronom démonstratif', 508),
#  ('pronom interrogatif', 487),
#  ('particule', 478),
#  ('variante par contrainte typographique', 397),
#  ('locution phrase', 396),
#  ('onomatopée', 381),
#  ('adverbe interrogatif', 352),
#  ('particule numérale', 350),
#  ('radical', 346),
#  ('adjectif indéfini', 344),
#  ('erreur', 290),
#  ('pronom possessif', 285),
#  ('pronom relatif', 277),
#  ('adjectif démonstratif', 265),
#  ('article défini', 257),
#  ('classificateur', 209),
#  ('conjonction de coordination', 153),
#  ('postposition', 140),
#  ('Voir aussi', 134),
#  ('article indéfini', 112),
#  ('verb', 108),
#  ('adv', 93),
#  ('notes', 76),
#  ('adjectif interrogatif', 67),
#  ('Prononciation', 66),
#  ('phrase', 65),
#  ('infixe', 60),
#  ('Étymologie', 57),
#  ('écriture', 53),
#  ('paronymes', 50),
#  ('proverbe', 49),
#  ('nom-pr', 42),
#  ('locution', 38),
#  ('adverbe relatif', 34),
#  ('Anagrammes', 33),
#  ('citations', 26),
#  ('quantificateur', 25),
#  ('nom propre ', 24),
#  ('article', 23),
#  ('déterminant', 18),
#  ('adjectif ', 18),
#  ('article partitif', 17),
#  ('anciennes orthographes', 16),
#  ('Notes', 16),
#  ('quasi-synonymes', 15),
#  ('abréviations', 14),
#  ('interfixe', 14),
#  ('phrases', 12),
#  ('adjectif exclamatif', 11),
#  ('adj-num', 11),
#  ('gismu', 10),
#  ('pronom-indéf', 10),
#  ('homophones', 9),
#  ('interj', 9),
#  ('nom ', 9),
#  ('substantif', 9),
#  ('Variante par contrainte typographique', 9),
#  ('onom', 9),
#  ('préposition ', 7),
#  ('affixe', 7),
#  ('faute d’orthographe', 7),
#  ('conj', 6),
#  ('pronom personnel ', 5),
#  ('composés', 5),
#  ('Variantes orthographiques', 5),
#  ('circonfixe', 5),
#  ('adverbe pronominal', 4),
#  ('dérivés', 4),
#  ('Prénom', 4),
#  ('verbe ', 4),
#  ('encl', 4),
#  ('nom-fam', 4),
#  ('Infixe', 4),
#  ('patronyme', 4),
#  ('Nom commun', 4),
#  ('Nom', 4),
#  ('prép', 4),
#  ('pré-verbe', 4),
#  ('Variantes', 4),
#  ('conjonction ', 3),
#  ('Traductions', 3),
#  ('Nom propre', 3),
#  ('adjectif relatif', 3),
#  ('préf', 3),
#  ('faute', 3),
#  ('faux-amis', 3),
#  ('Synonymes', 3),
#  ('gentilés', 3),
#  ('Adverbe', 3),
#  ('variantes orthographiques', 3),
#  ('Pronom démonstratif', 3),
#  ('adverbe indéfini', 2),
#  ('copule', 2),
#  ('synonymes', 2),
#  ('Adjectif', 2),
#  ('class', 2),
#  ('prov', 2),
#  ('interjection ', 2),
#  ('Préposition', 1),
#  ('Pronom', 1),
#  ('var-ortho', 1),
#  ('adj-excl', 1),
#  ('adjectif numéral ', 1),
#  ('pronom ', 1),
#  ('expressions', 1),
#  ('adv-pron', 1),
#  ('article indéfini ', 1),
#  ('', 1),
#  ('enclitique', 1),
#  ('pré-nom', 1),
#  ('suff', 1),
#  ('diminutifs', 1),
#  ('Pronom personnel', 1),
#  (' adjectif ', 1),
#  ('attestations', 1),
#  ('variantes', 1),
#  ('adverbe interrogatif ', 1),
#  ('Adverbe interrogatif', 1),
#  ('prénom ', 1),
#  ('pronom indéfini ', 1),
#  ('adverbe ', 1),
#  ('Suffixe', 1),
#  ('suffixe ', 1),
#  ('Locution-phrase', 1),
#  ('sources', 1),
#  ('bibliographie', 1)]

# %%
# Mapping with Universal Dependencies Part-of-Speech tags
TAGS = {
    "ADJ": {
        "adj",
        "adj-excl",
        "adjectif",
        "adjectif démonstratif",
        "adjectif exclamatif",
        "adjectif indéfini",
        "adjectif interrogatif",
        "adjectif possessif",
        "adjectif relatif",
    },
    "ADP": {
        "particule",
        "particule numérale",
        "postposition",
        "prép",
        "préposition",
    },
    "ADV": {
        "adv",
        "adv-pron",
        "adverbe",
        "adverbe indéfini",
        "adverbe interrogatif",
        "adverbe pronominal",
        "adverbe relatif",
    },
    "CCONJ": {
        "conjonction de coordination",
    },
    "DET": {
        "article",
        "article défini",
        "article indéfini",
        "article partitif",
        "déterminant",
    },
    "INTJ": {
        "interj",
        "interjection",
        "onom",
        "onomatopée",
    },
    "NOUN": {
        "nom",
        "nom commun",
        "nom scientifique",
    },
    "NUM": {
        "adjectif numéral",
        "adj-num",
        "numéral",
    },
    "PART": {
        # Not meaningful as a stand-alone word
    },
    "PRON": {
        "pronom",
        "pronom démonstratif",
        "pronom indéfini",
        "pronom interrogatif",
        "pronom personnel",
        "pronom possessif",
        "pronom relatif",
        "pronom-indéf",
    },
    "PROPN": {
        "nom propre",
        "nom-pr",
        "nom de famille",
        "nom-fam",
        "prénom",
    },
    "PUNCT": {
        # Tagged as SYM, as Wiktionary do not differentiate between them
    },
    "SCONJ": {
        "conj": "",
        "conjonction": "",
    },
    "SYM": {
        "lettre",
        "symbole",
        "sinogramme",
        "dico sinogrammes",
    },
    "VERB": {
        "verbe",
        "verb",
    },
}

# Invert mapping
MAPPING = {v: k for k, vs in TAGS.items() for v in vs}
